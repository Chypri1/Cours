# %%
##Exercice 1 TD2
"""
def convexes(l,debut):
    min=l[debut]
    for i in range(len(l)):
        if l[i]<min:
            min=l[i]
    return min
"""
debut=0

def min_dicho(l:list,debut:int):
    pos=len(l)//2
    if(l[pos]<l[pos-1] and l[pos]<l[pos+1]):
        return pos
    elif l[pos+1]<l[pos]:
        return min_dicho(l[pos:],debut=pos+debut)
    else:
        return min_dicho(l[:pos+1],debut=debut)


##Exercice 2 TD2

def get_index(l:list,v:int,debut=0):
    if len(l)<=0 :
        return -1
    pos=len(l)//2
    if l[pos]==v:
        return pos+debut
    elif l[pos]<v:
        return get_index(l[pos+1:],v,pos+1+debut)
    else:
        return get_index(l[:pos],v,debut)

#####    fonction intermédiaire pour connaitre la position dans l'index 
def pos_dicho(l:list,v:int,debut=0):
    if len(l)==0 :
        return debut
    pos=len(l)//2
    if l[pos]==v:
        return pos+debut
    elif l[pos]<v:
        return pos_dicho(l[pos+1:],v,pos+1+debut)
    else:
        return pos_dicho(l[:pos],v,debut)
